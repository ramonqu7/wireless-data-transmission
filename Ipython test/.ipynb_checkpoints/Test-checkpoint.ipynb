# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
import zlib
import blosc

# %%
def Depth2Gray(d4d):
        d4d = 255 - cv2.cvtColor(d4d, cv2.COLOR_GRAY2RGB)
        return d4d

# %% [markdown]
# ### Test Compression Tools for Depth and Color Images

# %%
def depth_compress(i):
    name = "apple_1/apple_1_1_"
    filename = name+str(i)+"_depth.png"
    depth = cv2.imread(filename)
    plt.imshow(depth)
    plt.show()
    return len(depth), len(zlib.compress(depth.tostring())), len(blosc(depth.tostring()))
def color_compress(i):
    name = "apple_1/apple_1_1_"
    filename = name+str(i)+".png"
    color = cv2.imread(filename)
    return len(color), len(zlib.compress(color.tostring())), len(blosc(color.tostring()))

# %%
td = 0
zd = 0
bd = 0
tc = 0
zc = 0
bc = 0
for i in range(1, 209):
    t,z,b = depth_compress(i)
    td += t
    zd += z
    bd += b
    tzb = color_compress(i)
    tc += t
    zc += z
    bc += b
td /= 208.0
bd /= 208.0
zd /= 208.0
tc /= 208.0
zc /= 208.0
bc /= 208.0
print("Depth:")
print("After Native Zlib Compression:",zd , 
      "; Compression Rate:",zd/td*100)
print("After Blosc Compression:", bd, 
      "; Compression Rate:",bd/td*100)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-50-deb23e6a31c6> in <module>()
#       6 bc = 0
#       7 for i in range(1, 209):
# ----> 8     t,z,b = depth_compress(i)
#       9     td += t
#      10     zd += z
#
# <ipython-input-49-f0ea4c215dee> in depth_compress(i)
#       3     filename = name+str(i)+"_depth.png"
#       4     depth = cv2.imread(filename)
# ----> 5     plt.imshow(depth)
#       6     plt.show()
#       7     return len(depth), len(zlib.compress(depth.tostring())), len(blosc(depth.tostring()))
#
# c:\users\ramon qu\appdata\local\programs\python\python35-32\lib\site-packages\matplotlib\pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, hold, data, **kwargs)
#    3099                         filternorm=filternorm, filterrad=filterrad,
# ...

# %%
print("After Native Zlib Compression:", len(zlib.compress(depth.tostring())), 
      "; Compression Rate:",len(zlib.compress(depth.tostring()))*1.0/len(depth.tostring())*100)

print("After Blosc Compression:", len(blosc.compress(depth.tostring(), cname="zlib")), 
      "; Compression Rate:",len(blosc.compress(depth.tostring(), cname="zlib"))*1.0/len(depth.tostring())*100)
len(depth.tostring())
# Out:
# After Native Zlib Compression: 39106 ; Compression Rate: 4.243272569444445
# After Blosc Compression: 140808 ; Compression Rate: 15.278645833333334
# 921600

# %%
color = np.uint8(np.random.randint(255,size = (480,640,3)))

# %%
plt.imshow(color)
plt.show()
print("Origin color Array Data Size: "+str(len(color.tostring())))
# Out:
# Origin color Array Data Size: 921600

# %%
print("After Native Zlib Compression:", len(zlib.compress(color.tostring())),
      "; Compression Rate:",len(zlib.compress(color.tostring()))*1.0/len(color.tostring()))

print("After Native Zlib Compression:", len(blosc.pack_array(color)),
      "; Compression Rate:",len(blosc.pack_array(color))*1.0/len(color.tostring()))
# Out:
# After Native Zlib Compression: 921891 ; Compression Rate: 1.0003157552083333
# After Native Zlib Compression: 921780 ; Compression Rate: 1.0001953125

# %%
rgbd = np.dstack((color, depth))

# %%
print("Before Compression:",
      len(rgbd.tostring()),
      "After Native Zlib Compression:", len(zlib.compress(rgbd.tostring())),
      "; Compression Rate:",len(zlib.compress(rgbd.tostring()))*1.0/len(rgbd.tostring()))

print("Before Compression:",
      len(rgbd.tostring()),
      "After Blosc Compression:", len(blosc.compress(rgbd.tostring(),cname="zlib")),
      "; Compression Rate:",len(blosc.compress(rgbd.tostring(),cname="zlib"))*1.0/len(rgbd.tostring()))
# Out:
# Before Compression: 1843200 After Native Zlib Compression: 1285461 ; Compression Rate: 0.6974072265625
# Before Compression: 1843200 After Blosc Compression: 1448868 ; Compression Rate: 0.7860611979166666
